# %%
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np


(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train[..., np.newaxis] / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)
datagen.fit(x_train)

def build_model():
    model = models.Sequential([
        layers.Input(shape=(28, 28, 1)),

        layers.Conv2D(64, 3, activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(64, 3, activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Dropout(0.25),

        layers.Conv2D(128, 3, activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(128, 3, activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Dropout(0.25),

        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(10, activation='softmax')
    ])
    return model

model = build_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, verbose=1)
early_stop = callbacks.EarlyStopping(monitor='val_accuracy', patience=8, restore_best_weights=True)

history = model.fit(
    datagen.flow(x_train, y_train, batch_size=128),
    epochs=50,
    validation_data=(x_test, y_test),
    callbacks=[reduce_lr, early_stop],
    verbose=2
)

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Final Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 469/469 - 37s - 79ms/step - accuracy: 0.9153 - loss: 0.8196 - val_accuracy: 0.4784 - val_loss: 1.5413 - learning_rate: 1.0000e-03
# Epoch 2/50
# 469/469 - 20s - 42ms/step - accuracy: 0.9782 - loss: 0.6250 - val_accuracy: 0.9890 - val_loss: 0.5745 - learning_rate: 1.0000e-03
# Epoch 3/50
# 469/469 - 18s - 39ms/step - accuracy: 0.9850 - loss: 0.5951 - val_accuracy: 0.9945 - val_loss: 0.5418 - learning_rate: 1.0000e-03
# Epoch 4/50
# 469/469 - 19s - 41ms/step - accuracy: 0.9875 - loss: 0.5817 - val_accuracy: 0.9934 - val_loss: 0.5412 - learning_rate: 1.0000e-03
# Epoch 5/50
# 469/469 - 18s - 39ms/step - accuracy: 0.9890 - loss: 0.5735 - val_accuracy: 0.9939 - val_loss: 0.5351 - learning_rate: 1.0000e-03
# Epoch 6/50
# 469/469 - 19s - 40ms/step - accuracy: 0.9903 - loss: 0.5678 - val_accuracy: 0.9961 - val_loss: 0.5288 - learning_rate: 1.0000e-03
# Epoch 7/50
# 469/469 - 18s - 39ms/step - accuracy: 0.9914 - loss: 0.5620 - val_accuracy: 0.9950 - val_loss: 0.5356 - learning_rate: 1.0000e-03
# Epoch 8/50
# 469/469 - 19s - 40ms/step - accuracy: 0.9920 - loss: 0.5585 - val_accuracy: 0.9936 - val_loss: 0.5353 - learning_rate: 1.0000e-03
# Epoch 9/50
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 469/469 - 18s - 39ms/step - accuracy: 0.9924 - loss: 0.5559 - val_accuracy: 0.9960 - val_loss: 0.5252 - learning_rate: 1.0000e-03
# Epoch 10/50
# 469/469 - 19s - 40ms/step - accuracy: 0.9942 - loss: 0.5483 - val_accuracy: 0.9956 - val_loss: 0.5225 - learning_rate: 5.0000e-04
# Epoch 11/50
# 469/469 - 18s - 39ms/step - accuracy: 0.9938 - loss: 0.5467 - val_accuracy: 0.9962 - val_loss: 0.5225 - learning_rate: 5.0000e-04
# Epoch 12/50
# 469/469 - 19s - 40ms/step - accuracy: 0.9942 - loss: 0.5451 - val_accuracy: 0.9965 - val_loss: 0.5230 - learning_rate: 5.0000e-04
# Epoch 13/50
# 469/469 - 18s - 39ms/step - accuracy: 0.9946 - loss: 0.5436 - val_accuracy: 0.9959 - val_loss: 0.5236 - learning_rate: 5.0000e-04
# Epoch 14/50
# 469/469 - 19s - 41ms/step - accuracy: 0.9951 - loss: 0.5424 - val_accuracy: 0.9963 - val_loss: 0.5257 - learning_rate: 5.0000e-04
# Epoch 15/50
# 469/469 - 19s - 40ms/step - accuracy: 0.9949 - loss: 0.5423 - val_accuracy: 0.9968 - val_loss: 0.5347 - learning_rate: 5.0000e-04
# Epoch 16/50
# 469/469 - 20s - 43ms/step - accuracy: 0.9951 - loss: 0.5407 - val_accuracy: 0.9957 - val_loss: 0.5224 - learning_rate: 5.0000e-04
# Epoch 17/50
# 469/469 - 19s - 40ms/step - accuracy: 0.9954 - loss: 0.5395 - val_accuracy: 0.9967 - val_loss: 0.5176 - learning_rate: 5.0000e-04
# Epoch 18/50
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 469/469 - 19s - 40ms/step - accuracy: 0.9952 - loss: 0.5392 - val_accuracy: 0.9960 - val_loss: 0.5167 - learning_rate: 5.0000e-04
# Epoch 19/50
# 469/469 - 19s - 40ms/step - accuracy: 0.9959 - loss: 0.5356 - val_accuracy: 0.9969 - val_loss: 0.5150 - learning_rate: 2.5000e-04
# Epoch 20/50
# 469/469 - 18s - 39ms/step - accuracy: 0.9968 - loss: 0.5338 - val_accuracy: 0.9970 - val_loss: 0.5147 - learning_rate: 2.5000e-04
# Epoch 21/50
# 469/469 - 19s - 40ms/step - accuracy: 0.9967 - loss: 0.5334 - val_accuracy: 0.9971 - val_loss: 0.5150 - learning_rate: 2.5000e-04
# Epoch 22/50
# 469/469 - 18s - 39ms/step - accuracy: 0.9970 - loss: 0.5327 - val_accuracy: 0.9970 - val_loss: 0.5145 - learning_rate: 2.5000e-04
# Epoch 23/50
# 469/469 - 19s - 40ms/step - accuracy: 0.9965 - loss: 0.5329 - val_accuracy: 0.9969 - val_loss: 0.5145 - learning_rate: 2.5000e-04
# Epoch 24/50
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 469/469 - 18s - 39ms/step - accuracy: 0.9968 - loss: 0.5323 - val_accuracy: 0.9963 - val_loss: 0.5159 - learning_rate: 2.5000e-04
# Epoch 25/50
# 469/469 - 20s - 43ms/step - accuracy: 0.9971 - loss: 0.5312 - val_accuracy: 0.9965 - val_loss: 0.5142 - learning_rate: 1.2500e-04
# Epoch 26/50
# 469/469 - 21s - 45ms/step - accuracy: 0.9969 - loss: 0.5305 - val_accuracy: 0.9970 - val_loss: 0.5141 - learning_rate: 1.2500e-04
# Epoch 27/50
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 469/469 - 18s - 39ms/step - accuracy: 0.9976 - loss: 0.5295 - val_accuracy: 0.9969 - val_loss: 0.5135 - learning_rate: 1.2500e-04
# Epoch 28/50
# 469/469 - 19s - 40ms/step - accuracy: 0.9976 - loss: 0.5290 - val_accuracy: 0.9968 - val_loss: 0.5136 - learning_rate: 6.2500e-05
# Epoch 29/50
# 469/469 - 18s - 39ms/step - accuracy: 0.9978 - loss: 0.5286 - val_accuracy: 0.9970 - val_loss: 0.5136 - learning_rate: 6.2500e-05
# Final Test Accuracy: 99.71%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='o')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)

plt.tight_layout()
plt.show()
